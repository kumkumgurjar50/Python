# %%
from random import*
for i in range(10):
    for x in range(6):
        print(randint(0,9),end="")
    print()
# Out:
# 564567
# 592600
# 876140
# 752333
# 828531
# 607782
# 878759
# 749255
# 866020
# 844358

# %%
from random import*
for i in range(10):
    for x in range(1,7):
        if x%2==1:
            print(chr(randint(65,90)),end="")
        else:
            print(randint(0,9),end="")
    print()
# Out:
# E6D3Y5
# O5T0C1
# T8V1Z2
# I0K1Z7
# G0Q0U2
# V9N8F5
# P2L7R1
# U6R6A1
# K5M3P1
# Q8I1D8

# %%
import sys
print(sys.version)
# Out:
# 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]

# %%
def cust_data():
    name=input("Enter name:")
    age=int(input("Enter age:"))
    data=str([name,age])
    f=open("customer.txt","a")
    f.write(data)
    f.close()
cust_data()
f=open("customer.txt")
r=f.read()
print(r)
# Out:
# Enter name: kumkum
# Enter age: 19
# ['kumkum', 19]['kumkum', 19]

# %%
f=open("city.txt","w+")
f.write("This city is very clean")
f.seek(0)
data=f.read()
print(data)
# Out:
# This city is very clean

# %%
def count_lines():
    count=0
    f=open("friends.txt","r")
    data=f.readlines()
    for i in data:
        count+=1
    print(count)
count_lines()
# Out:
# 4

# %%
def countline(f):
#file_read=f.readlines()
   count=0
   for lines in f:
       count+=1
   print(count)
f=open("friends.txt")
countline(f)
# Out:
# 4

# %%
def oddlines(f):
    count=0
    for line in f:
        if count%2==1:
            print(line)
        count+=1
f=open("friends.txt","r")
oddlines(f)
# Out:
# Friends are honest, Friends are best !
#
# We are nothing without friends, Life is not possible without friends !

# %%
def oddline(f):
#file_read=f.readlines()
     countLine=0
     words=0
     for lines in f:
          countLine+=1
          for word in lines.split():
               words+=1
     print(countLine,words)
f=open("friends.txt")
oddline(f)
# Out:
# 4 36

# %%
# %%writefile sample1.txt
# vishal is best in python
# B2,B7 and D1 are best in python
# Out:
# Writing sample1.txt

# %%
f=open("sample1.txt")
data=f.read()
data=data.upper()
f.close()
f=open("output.txt","w")
f.write(data)
f.close()
f=open("output.txt")
print(f.read())
# Out:
# VISHAL IS BEST IN PYTHON
# B2,B7 AND D1 ARE BEST IN PYTHON

# %%
# %%writefile 1.txt
# vishal acharya
# b2
# Out:
# Writing 1.txt

# %%
# %%writefile 2.txt
# python
# b7,d1
# Out:
# Writing 2.txt

# %%
file1=open("1.txt")
file2=open("1copy.txt","w")
for lines in file1:
      file2.write(lines)
file1.close()
file2.close()
f=open("1copy.txt")
print(f.read())
# Out:
# vishal acharya
# b2

# %%
f=open('friends.txt')
lines=f.readlines()
word=input("enter word: ")
for row in lines:
     #print(row.find(word))
     if row.find(word)!=-1:
           print('string exists in file')
           print('line Number:',lines.index(row),row.index(word))
           print(row)
f.close()
# Out:
# enter word:  without
# -1
# -1
# -1
# 15
# string exists in file
# line Number: 3 15
# We are nothing without friends, Life is not possible without friends !

# %%
f=open("f1.txt","w")
data="Hello"
for i in range(1001):
    f.write(data)
f.close()

# %%
# %%writefile example1.txt
# Friends are crazy, Friends are naughty !
# Friends are honest, Friends are best !
# Out:
# Writing example1.txt

# %%
f=open("example1.txt","r")
data=f.read()
f.close()
data1=data[::-1]
f1=open("example2.txt","w")
f1.write(data1)
# Out:
# 80

# %%
with open("example1.txt", "r") as f1:
        data = f1.read()
rev_data = data[::-1]
with open("file2.txt", "w") as f2:
        f2.write(rev_data)
f3=open("file2.txt","r")
d=f3.read()
d1=d.upper()
f4=open("file3.txt","w")
f4.write(d1)
f4.close()
f4=open("file3.txt","r")
data4=f4.read()
vowel=0
for i in data4:
    if i in "AEIOU":
        vowel+=1
print(vowel)
f4.close()
f5=open("file3.txt","r")
data5=f5.readlines()
if len(data5)>=2:
    print(data5[1])
# Out:
# 22
# ! TSEB ERA SDNEIRF ,TSENOH ERA SDNEIRF

# %%
f=open("friends.txt","r")
data=f.readlines()
f.close()
for i in data:
    for j in i.split():
        if len(j)==4 and j[0]==j[-1]:
            print(j)
# Out:
# hihh
# dfgd
# ghjg
# 1231

# %%
# %%writefile Story.txt
# INDIA IS MY COUNTRY
# Out:
# Overwriting Story.txt

# %%
f=open("Story.txt","r")
data=f.read().split()
f.close()
result=" "
for i in data:
    if i[0]=='i' or i[0]=='I':
        result=result+i[::-1]+" "
    else:
        result=result+i+" "
print(result)
# Out:
#  AIDNI SI MY COUNTRY

# %%
# %%writefile python.txt
# Python is a Easy Subject
# OOPs is One of the most
# interesting Topic
# Out:
# Writing python.txt

# %%
# %%writefile file5.txt
# This is line 1
# This is line 2
# This is line 3
# This is line 4
# This is line 5
# Out:
# Writing file5.txt

# %%
f=open("file5.txt")
data=f.read()
l=[]
for i in data:
    l1=i.split()
    l.append(i[0])
print(l)
# Out:
# ['T', 'h', 'i', 's', ' ', 'i', 's', ' ', 'l', 'i', 'n', 'e', ' ', '1', '\n', 'T', 'h', 'i', 's', ' ', 'i', 's', ' ', 'l', 'i', 'n', 'e', ' ', '2', '\n', 'T', 'h', 'i', 's', ' ', 'i', 's', ' ', 'l', 'i', 'n', 'e', ' ', '3', '\n', 'T', 'h', 'i', 's', ' ', 'i', 's', ' ', 'l', 'i', 'n', 'e', ' ', '4', '\n', 'T', 'h', 'i', 's', ' ', 'i', 's', ' ', 'l', 'i', 'n', 'e', ' ', '5', '\n']

# %%
f=open("file5.txt")
c1=c2=c3=0
for i in f.read():
    if i==" ":
        c1+=1
        c2+=1
        c3+=1
    elif i=="\n":
        c2+=1
    else:
        c3+=1
print(c1,c2,c3)
# Out:
# 15 20 70

# %%
with open("B7.txt", 'w') as file:
      while True:
            user_input = input("Enter a string/sentence (type 'END' to stop): ")
            if user_input.upper() == 'END':
                  break
            file.write(user_input + '\n')
with open("B7.txt", 'r') as file: 
    while True:
        x=file.readline()
        if len(x)!=0:
            if x1[0].isupper():
                print(x)
        else:
            break
# Out:
# Enter a string/sentence (type 'END' to stop):  shdj
# Enter a string/sentence (type 'END' to stop):  HJu
# Enter a string/sentence (type 'END' to stop):  gHJ
# Enter a string/sentence (type 'END' to stop):  gYYY
# Enter a string/sentence (type 'END' to stop):  DHI]D
# Enter a string/sentence (type 'END' to stop):  HDI
# Enter a string/sentence (type 'END' to stop):  END
# DHI]D
#
# HDI

# %%
# %%writefile python1.txt
# Friends are crazy, Friends are naughty !
# Friends are honest, Friends are best !
# Friends are like keygen, friends are like license key !
# new We are nothing without friends, Life is not possible without friends !
# Out:
# Writing python1.txt

# %%
# %%writefile python2.txt
# Friends are crazy, Friends are naughty !
# Friends 6re honest, Friends are best !
# Friends are like keygen, friends are like license key !
# new We are nothing without friends, Life is not possible without friends !
# Out:
# Writing python2.txt

# %%
f1 = open("python1.txt", "r")
f2 = open("python2.txt", "r")
fileOne = f1.readlines()
fileTwo = f2.readlines()
f1.close()
f2.close()
for index,line in enumerate(fileOne):
      if line!= fileTwo[index]:
           for ind,char in enumerate(line):
                if char!=fileTwo[index][ind]:
                      print("line number",index+1,"colum",ind+1)
                      break
# Out:
# line number 2 colum 9

# %%
f=open("python1.txt")
d={}
f1=f.readlines()
for line in f1:
     for words in line.split():
           d[words]=d.get(words,0)+1
#print(d)
for i,j in d.items():
     print(i,"-",j,end=",")
# Out:
# Friends - 5,are - 7,crazy, - 1,naughty - 1,! - 4,honest, - 1,best - 1,like - 2,keygen, - 1,friends - 2,license - 1,key - 1,new - 1,We - 1,nothing - 1,without - 2,friends, - 1,Life - 1,is - 1,not - 1,possible - 1,

# %%
class Student:
    student_list = []
    def __init__(self, name, rollnumber, marks1, marks2):
            self.name = name
            self.rollnumber = rollnumber
            self.marks1 = marks1
            self.marks2 = marks2
            Student.student_list.append(self)
    def accept(self):
            name = input("Enter student name: ")
            rollnumber = int(input("Enter roll number: "))
            marks1 = int(input("Enter marks for subject 1: "))
            marks2 = int(input("Enter marks for subject 2: "))
            s1=Student(name,rollnumber,marks1,marks2)
            print(f"Student {name} added with {rollnumber} successfully")
    def display(self):
        for s in Student.student_list:
            print(f"\nName : {s.name}\nRollNo : {s.rollnumber}\nMarks1 : {s.marks1}\nMarks2 : {s.marks2}")
    def search(self):
        roll=int(input("Enter search rollno."))
        for s in Student.student_list:
            if s.rollnumber==roll:
                print(f"\nName : {s.name}\nRollNo : {s.rollnumber}\nMarks1 : {s.marks1}\nMarks2 : {s.marks2}")
            else:
                print("student not found")
    def delete(self):
        roll=int(input("Enter rollno."))
        for s in Student.student_list:
            if s.rollnumber==roll:
                Student.student_list.remove(s)
                print("\nList after deletion")
                self.display()
                return
            else:
                print("student not found")
    def update(self):
        roll=int(input("Enter rollno."))
        newroll=int(input("Enter rollno."))
        for s in Student.student_list:
            if s.rollnumber==roll:
                s.rollnumber==newroll
                print("\nList after deletion")
                self.display()
                return
            else:
                print("student not found")
student_system = Student("vishal",1,10,9)

# %%
student_system.accept()
# Out:
# Enter student name:  kumkum
# Enter roll number:  2
# Enter marks for subject 1:  123
# Enter marks for subject 2:  123
# Student kumkum added with 2 successfully

# %%
student_system.accept()
student_system.accept()
# Out:
# Enter student name:  pooja
# Enter roll number:  3
# Enter marks for subject 1:  100
# Enter marks for subject 2:  100
# Student pooja added with 3 successfully
# Enter student name:  alisha
# Enter roll number:  4
# Enter marks for subject 1:  100
# Enter marks for subject 2:  100
# Student alisha added with 4 successfully

# %%
student_system.display()
# Out:
# Name : vishal
# RollNo : 1
# Marks1 : 10
# Marks2 : 9
#
# Name : kumkum
# RollNo : 2
# Marks1 : 100
# Marks2 : 100
#
# Name : pooja
# RollNo : 3
# Marks1 : 100
# Marks2 : 100
#
# Name : alisha
# RollNo : 4
# Marks1 : 100
# Marks2 : 100

# %%
student_system.delete()
# Out:
# Enter rollno. 1
# List after deletion
#
# Name : kumkum
# RollNo : 2
# Marks1 : 100
# Marks2 : 100
#
# Name : pooja
# RollNo : 3
# Marks1 : 100
# Marks2 : 100
#
# Name : alisha
# RollNo : 4
# Marks1 : 100
# Marks2 : 100

# %%
student_system.update()
# Out:
# Enter rollno. 1
# Enter rollno. 4
# List after deletion
#
# Name : vishal
# RollNo : 1
# Marks1 : 10
# Marks2 : 9
#
# Name : kumkum
# RollNo : 2
# Marks1 : 123
# Marks2 : 123

# %%
class InvalidToppingError(Exception):
    pass
class InvalidCheesError(Exception):
    pass
class pizza:
    def __init__(self, size, toppings, cheese):
        self.size = size
        self.toppings = toppings
        self.cheese = cheese

# %%
f=open("abcd.txt",'w')
list=["sunny\n","bunny\n","vinny\n","chinny"]
f.writelines(list)
print("List of lines written to the file successfully")
f.close()
f=open("abcd.txt")
print(f.read())
f.close()
# Out:
# List of lines written to the file successfully
# sunny
# bunny
# vinny
# chinny

# %%
f=open('abcd.txt','r')
while True:
  data=f.readline()
  if data=='':
      break
  else:
      print(data)
f.close()
# Out:
# sunny
#
# bunny
#
# vinny
#
# chinny

# %%
f1=open('file5.txt')
f2=open('file2.txt','w')
for line in f1:
 #f2.write(line.upper())
f1.close()
f2.close()
with open('file2.txt') as f:
 print(f.read())
# Out:
# This is line 1

# %%
pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.10.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.5
# attrs                     25.3.0
# babel                     2.17.0
# beautifulsoup4            4.13.5
# bleach                    6.2.0
# certifi                   2025.8.3
# cffi                      2.0.0
# charset-normalizer        3.4.3
# colorama                  0.4.6
# comm                      0.2.3
# debugpy                   1.8.16
# decorator                 5.2.1
# defusedxml                0.7.1
# executing                 2.2.1
# fastjsonschema            2.21.2
# fqdn                      1.5.1
# h11                       0.16.0
# httpcore                  1.0.9
# httpx                     0.28.1
# idna                      3.10
# ipykernel                 6.30.1
# ipython                   9.5.0
# ipython_pygments_lexers   1.1.1
# isoduration               20.11.0
# jedi                      0.19.2
# Jinja2                    3.1.6
# json5                     0.12.1
# jsonpointer               3.0.0
# jsonschema                4.25.1
# jsonschema-specifications 2025.9.1
# jupyter_client            8.6.3
# jupyter_core              5.8.1
# jupyter-events            0.12.0
# jupyter-lsp               2.3.0
# jupyter_server            2.17.0
# jupyter_server_terminals  0.5.3
# jupyterlab                4.4.7
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.27.3
# lark                      1.2.2
# MarkupSafe                3.0.2
# matplotlib-inline         0.1.7
# mistune                   3.1.4
# nbclient                  0.10.2
# nbconvert                 7.16.6
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# notebook                  7.4.5
# notebook_shim             0.2.4
# packaging                 25.0
# pandocfilters             1.5.1
# parso                     0.8.5
# pip                       25.2
# platformdirs              4.4.0
# prometheus_client         0.22.1
# prompt_toolkit            3.0.52
# psutil                    7.0.0
# pure_eval                 0.2.3
# pycparser                 2.23
# Pygments                  2.19.2
# python-dateutil           2.9.0.post0
# python-json-logger        3.3.0
# pywin32                   311
# pywinpty                  3.0.0
# PyYAML                    6.0.2
# pyzmq                     27.1.0
# referencing               0.36.2
# requests                  2.32.5
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rfc3987-syntax            1.1.0
# rpds-py                   0.27.1
# Send2Trash                1.8.3
# setuptools                80.9.0
# six                       1.17.0
# sniffio                   1.3.1
# soupsieve                 2.8
# stack-data                0.6.3
# terminado                 0.18.1
# tinycss2                  1.4.0
# tornado                   6.5.2
# traitlets                 5.14.3
# types-python-dateutil     2.9.0.20250822
# typing_extensions         4.15.0
# uri-template              1.3.0
# urllib3                   2.5.0
# wcwidth                   0.2.13
# webcolors                 24.11.1
# webencodings              0.5.1
# websocket-client          1.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
l="kumkum"
l1=l.split()
print(l1)
# Out:
# ['kumkum']

# %%
f=open("fi1.txt","w")
l=["a","b"]
f.writelines(l)
f.write("kumkum")
# Out:
# 6
