# %%
#Write a program to check whether a number is Armstrong number or not
a=int(input("Enter number: "))
temp=a
count=0
while a!=0:
    a//=10
    count+=1
a=temp
sum=0
while a!=0:
    r=a%10
    sum=sum+r**count
    a//=10
if temp==sum:
    print("Number is Armstrong")
else:
    print("Number is not Armstrong")
# Out:
# Enter number:  123
# Number is not Armstrong

# %%
#Write a program to check whether a number is Armstrong number or not
a=int(input("Enter number: "))
temp=a
b=str(a)
count=len(b)
a=temp
sum=0
while a!=0:
    r=a%10
    sum=sum+r**count
    a//=10
if temp==sum:
    print("Number is Armstrong")
else:
    print("Number is not Armstrong")
# Out:
# Enter number:  123
# Number is not Armstrong

# %%
a=int(input("Enter n:"))
for i in range(a):
    for j in range(i+1):
        print("*",end=" ")
    print()
# Out:
# Enter n: 5
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
s=input("enter a string: ")
s = s.title()
result = ""
print(s)
for word in s.split():
     result += word[:-1] + word[-1].upper() + " "
print(result)
# Out:
# enter a string:  B2,B7 and D1 are best in python
# B2,B7 And D1 Are Best In Python
# B2,B7 AnD D1 ArE BesT IN PythoN
